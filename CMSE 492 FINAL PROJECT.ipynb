# %% [markdown]
# ## BY Kritika Saini

# %% [markdown]
# Finish the first draft of your project.
#
# Because of the timing of the semester, we will have normal classes through the final week of the semester. The project is due midnight on the final Friday of classes. I had hinted to some of you about a poster session, which I find really fun, but we would lose an entire week and add a lot of overhead in terms of preparing the posters.
#
# I am still getting questions about the size and scope of the project. Here are some broad guildelines:
# * the project is worth 30% of your grade, so you can do the math to scale to that size (e.g., how much time do you spend on a HW and what % of your grade it that?),
# * we started the semester with and end-to-end project to illustrate the size and scope of your project; that was Chapter 2 of your textbook; please review that chapter from the perspective of size and scope,
# * your textbook gives a step-by-step guide for a project in the appendix; this appendix is either in the back of the book (first and second editions) or online (third edition),
# * you now have feedback from reviews from other students who used a rubric; pay close attention to that feedback because a similar rubric will be used for the final version of your project.
#
# To add to that, your grade will be computed using two, very-broad categories:
# 1. **<font color=#BBBBFF>30%:</font>** The big picture. Do you have a "real" problem that has a "real" question to be answered? The goal here is to ensure that you can approach a problem, apply ML to it, be able to answer the question and deploy the final result.
# 2. **<font color=#BBBBFF>70%:</font>** You use the _complete_ ML workflow from EDA to hyperparameter tuning and scoring/metrics.
#
# There are two main ways to deploy your app: a complete GitHub page and/or a web app (e.g., using Dash, Streamlit, ...). There are two goals here:
# 1. you take the project to completion,
# 2. you have something to link to from your CV.
#
# As mentioned numerous times, you are given considerable flexibility within the spirit of these guidelines. It has been great to hear about all of your projects and I think we have shaped many of them to contain this spirit. In fact, some of the most interesting areas of ML don't naturally fit into a simple box (e.g., NLP, RL).
#
# In terms of writing, your report should be written and formatted at a professional level. I assume you all have access to GPT-4, so that sets the _lower_ bar on the writing standard. You should have no less than 3000 words and there is no page limit. You should include all necesary equations and visualizations. Your visualizations should follow [professional standards](https://www.gooddata.com/blog/5-data-visualization-best-practices/):
# * all axes must be labeled,
# * some plots might require titles and/or legends and/or annotations,
# * the best/correct plot type should be used,
# * font size must be easy to read (and consistent within all plots),
# * if you write an app, use interactive plotting tools (e.g., Altair, Plotly),
# * plots must be very high quality (e.g., scalable PDF),
# * visualization can and should be used at all stages:
#   * EDA: missingness, pairplots, correlation plots
#   * training: learning curves
#   * metrics: confusion matrices
#   * and so on......
# * you get the idea....
#
# The reason there is no upper bound on the length of your report is that you can use as many equations and visualizations as you need.
#
# In a markdown cell below, write a detailed list of everything you need to do to complete your project, how long each step will take and when you will complete that task.
#
# #### Remember, report is organized and well-structured document. Try to these to have better structured report, by considering these suggestions
# * have clear sections and subsections
# * sections should have clear titles
# * equations should be numbered
# * code should be commented
# * provide caption for tables and figures (to improvde understanding)
# * figure or tables should convey a message (if not, it should be considered as part of appendix)
# * check for fluency and clarity within your context (typos, grammatical error, ...)
#
#
# #### For your report please follow one of these paths:
#
# 1. Here is a general format of a research paper [standard report](https://www.scribbr.com/category/research-paper/):
#
#
# 2. Here is the another suggested content organizaiton:
# * Introduction: big picture of the problem, your goals, your approach, why this interesting
# * Task Definition: formally define what you are doing (inputs, outputs)
# * Algorithm Definition: what algorithms did you use? (e.g., RL or DR or classification)
# * Machine Learning Approach
#   - DS/EDA methods
#   - ML approach/pipelines/tuning
#   - results, visualizations, comparisons
#   - discussion of results and conclusions about your goal
# * Summary, Conclusions and Remark
#   - recap your goal and what was achieved
#   - recap the methods you used
#   - what did you conclude from your study?
#   - future work: what were the shortcomings, what improvements can you propose?
# * Reference
# * Appendix
#   - your codes (there is no point in providing codes in previous sections)
#   - other supplementary materials

# %% [markdown]
# ## In a markdown cell below, write a detailed list of everything you need to do to complete your project, how long each step will take and when you will complete that task.

# %% [markdown]
# ## Report first draft

# %% [markdown]
# Individuals who display symptoms that are consistent with COVID-19 and those who have had high-risk exposure to SARS-CoV-2 should undergo testing for SARS-CoV-2 infection. Such testing should employ either a nucleic acid amplification test (NAAT) or an antigen test to detect SARS-CoV-2. Testing may also be used for screening and determining the length of a patient's isolation period.
#
# Several diagnostic tests for SARS-CoV-2 infection, including NAATs and antigen tests, have received Emergency Use Authorizations from the Food and Drug Administration (FDA). However, none of these diagnostic tests have been approved by the FDA. The diagnostic tests have been authorized for use in a variety of settings, including laboratory facilities, and point-of-care settings such as physician offices, pharmacies, long-term care facilities, and school clinics. These tests can be performed by trained personnel at or near the location where the specimen was collected.

# %% [markdown]
# The COVID-19 pandemic caused by the SARS-CoV-2 has had a significant impact on the global healthcare system, overwhelming ICU beds capacity and resulting in a high demand for testing. In an effort to slow the virus spread, the state and county of São Paulo, Brazil, implemented quarantine and social distancing measures. This report aims to predict the test result for SARS-Cov-2 (positive/negative) among suspected cases using anonymized data from patients seen at the Hospital Israelita Albert Einstein in São Paulo, Brazil. The dataset contains results of laboratory tests commonly collected during emergency room visits, which were standardized to have a mean of zero and a unit standard deviation. The prediction model could provide a practical solution to the limitations of testing during an overwhelmed healthcare system.

# %% [markdown]
# The SARS-CoV-2 test, like any other diagnostic test, has a possibility of turning out to be wrong. False negatives and false positives are both possible outcomes. A false negative means that the test result shows that the individual does not have the virus when in fact they do, while a false positive indicates that the individual is diagnosed with the virus when in fact they do not have it.
#
# The accuracy of the test depends on various factors such as the type of test used, the timing of the test, and the severity of the infection. For example, the accuracy of the SARS-CoV-2 test may be lower during the early stages of the infection, as the virus may not have replicated enough to be detected by the test. Similarly, the accuracy of the test may vary based on the type of test used. For instance, some studies have found that antigen tests are less accurate than nucleic acid amplification tests (NAATs), especially in asymptomatic individuals.
#
# It is crucial to check the accuracy of the SARS-CoV-2 test because an incorrect diagnosis can have serious consequences. False negatives can lead to the spread of the virus to others, and false positives can lead to unnecessary isolation, increased stress and anxiety, and diversion of resources away from other patients who may need it more urgently. Hence, it is crucial to consider the limitations and potential errors of the test when interpreting the results.

# %% [markdown]
# To achieve the objective of predicting SARS-Cov-2 test results, we will be utilizing various machine learning models, including Logistic Regression, Random Forest, K-nearest neighbor (KNN), Neural Networks (NN), Support Vector Machines (SVM), and Decision Trees. These models have been widely used in medical data analysis and have shown promising results.
#
# Logistic Regression is a widely used statistical method that predicts the probability of an event by fitting data to a logistic function. Random Forest is an ensemble learning method that constructs a multitude of decision trees at training time and outputs the mode of the classes as the prediction. KNN is a non-parametric algorithm that uses the similarity of feature vectors to classify a new data point. NN is a popular machine learning model that is composed of multiple layers of interconnected nodes and is trained to recognize patterns in data. SVM is a discriminative model that separates data into classes using a hyperplane in a high-dimensional space. Finally, Decision Trees are a popular algorithm that uses a tree-like model of decisions and their possible consequences to predict an outcome.
#
# I will be comparing the performance of these models based on their accuracy, precision, recall, and F1-score. I will also be performing feature selection to identify the most important features in the dataset that contribute to predicting the SARS-Cov-2 test result. The results of this analysis could provide valuable insights into predicting the test result for SARS-Cov-2 and help in managing the pandemic by identifying suspected cases more accurately and efficiently.

# %% [markdown]
# Based on preliminary investigation, I have found some interesting results.
# The negative cases are predominantly more than the positive cases, so there are 3 ways to go about preventing bias:
#
# 1. Data augmentation: I can generate synthetic data that balances the distribution of positive and negative samples.
#
# 2. Class weighting: I can assign a higher weight to the positive class during training to ensure that the model gives equal importance to both classes.
#
# 3. Evaluation metrics: I can use evaluation metrics that are sensitive to imbalanced datasets, such as precision, recall, F1-score, and AUC-ROC.

# %% [markdown]
# Cleaning of data was done in a complicated manner because this is a huge dataset and almost all the rows had 1 or more missing values. This was a big challeneg I faced.

# %% [markdown]
# I have also gone ahead and found the accuracies of different ML models. They are:
#
# 1. Logistic Regression accuracy: 0.893
#
# 2. Decision Trees accuracy: 0.882
#
# 3. Random Forest accuracy: 0.895
#
# 4. SVM accuracy: 0.894
#
# 5. KNN accuracy: 0.894
#
# 6. NN accuracy: 0.888
#
#
#
# The machine learning models were applied to the dataset to predict the SARS-Cov-2 test results and their accuracies were recorded. Based on the results obtained, it can be observed that the Random Forest model had the highest accuracy of 0.895, followed by SVM and KNN with accuracies of 0.894 each, and Logistic Regression with an accuracy of 0.893. Decision Trees had an accuracy of 0.882 and the Neural Network model had the lowest accuracy of 0.888.
#
# The high accuracies obtained indicate that the dataset contains relevant features that can be used to accurately predict the SARS-Cov-2 test results. The results also suggest that the Random Forest model is the most effective in predicting the test results for SARS-Cov-2 among the models tested. However, further analysis of the precision, recall, and F1-score of these models is required to obtain a better understanding of their performance. Feature selection techniques could also be used to identify the most important features in the dataset that contribute to predicting the SARS-Cov-2 test results. Overall, the results obtained provide valuable insights that could aid in managing the pandemic by identifying suspected cases more accurately and efficiently.

# %% [markdown]
# This report will continue when the final investigation has been done.........

# %% [markdown]
# References:
#
# https://www.covid19treatmentguidelines.nih.gov/overview/sars-cov-2-testing/

# %% [markdown]
# # Import

# %%
import pandas as pd

data = pd.read_excel('dataset.xlsx')

data.to_csv('filename.csv', index=False)

# %% [markdown]
# # Prelim

# %%
data.head()
# Out:
#         Patient ID  Patient age quantile SARS-Cov-2 exam result  \
# 0  44477f75e8169d2                    13               negative
# 1  126e9dd13932f68                    17               negative
# 2  a46b4402a0e5696                     8               negative
# 3  f7d619a94f97c45                     5               negative
# 4  d9e41465789c2b5                    15               negative
#
#    Patient addmited to regular ward (1=yes, 0=no)  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
#
#    Patient addmited to semi-intensive unit (1=yes, 0=no)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# ...

# %%
data.describe()
# Out:
#        Patient age quantile  Patient addmited to regular ward (1=yes, 0=no)  \
# count           5644.000000                                     5644.000000
# mean               9.318391                                        0.013997
# std                5.777903                                        0.117489
# min                0.000000                                        0.000000
# 25%                4.000000                                        0.000000
# 50%                9.000000                                        0.000000
# 75%               14.000000                                        0.000000
# max               19.000000                                        1.000000
#
#        Patient addmited to semi-intensive unit (1=yes, 0=no)  \
# count                                        5644.000000
# mean                                            0.008859
# std                                             0.093713
# ...

# %%
data.shape
# Out:
# (5644, 111)

# %%
data.columns
# Out:
# Index(['Patient ID', 'Patient age quantile', 'SARS-Cov-2 exam result',
#        'Patient addmited to regular ward (1=yes, 0=no)',
#        'Patient addmited to semi-intensive unit (1=yes, 0=no)',
#        'Patient addmited to intensive care unit (1=yes, 0=no)', 'Hematocrit',
#        'Hemoglobin', 'Platelets', 'Mean platelet volume ',
#        ...
#        'Hb saturation (arterial blood gases)',
#        'pCO2 (arterial blood gas analysis)',
#        'Base excess (arterial blood gas analysis)',
#        'pH (arterial blood gas analysis)',
#        'Total CO2 (arterial blood gas analysis)',
#        'HCO3 (arterial blood gas analysis)',
#        'pO2 (arterial blood gas analysis)', 'Arteiral Fio2', 'Phosphor',
#        'ctO2 (arterial blood gas analysis)'],
#       dtype='object', length=111)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

continuous_vars = data[['Hematocrit', 'Hemoglobin', 'Platelets', 'Mean platelet volume ', 'pCO2 (arterial blood gas analysis)', 'pH (arterial blood gas analysis)']]

corr_matrix = continuous_vars.corr()

sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation matrix of continuous variables')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.hist(data['Patient age quantile'], bins=20)
plt.xlabel('Age quantile')
plt.ylabel('Frequency')
plt.title('Age distribution of patients')
plt.show()

# %%
data['SARS-Cov-2 exam result'].value_counts().plot(kind='bar')
plt.xlabel('Exam result')
plt.ylabel('Count')
plt.title('Exam results')
plt.show()

# %%
plt.scatter(data['Hemoglobin'], data['Platelets'])
plt.xlabel('Hemoglobin')
plt.ylabel('Platelets')
plt.title('Hemoglobin vs. Platelets')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.hist(data["Hemoglobin"], bins=20)
plt.xlabel("Hemoglobin")
plt.ylabel("Frequency")
plt.show()

# %%
sns.boxplot(data=data[["Hematocrit", "Hemoglobin", "Platelets"]])
plt.show()

# %%
plt.hist([data["Hemoglobin"], data["Hb saturation (arterial blood gases)"]], bins=20, label=["Hemoglobin", "Hb saturation"])
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.legend()
plt.show()

# %%
plt.scatter(data["Platelets"], data["Mean platelet volume "])
plt.xlabel("Platelets")
plt.ylabel("Mean platelet volume")
plt.show()

# %%
plt.scatter(data["Platelets"], data["Mean platelet volume "], label="Platelets vs Mean platelet volume")
plt.scatter(data["pCO2 (arterial blood gas analysis)"], data["pH (arterial blood gas analysis)"], label="pCO2 vs pH")
plt.xlabel("Value")
plt.ylabel("Value")
plt.legend()
plt.show()

# %% [markdown]
# ## Other points that i come across:

# %% [markdown]
# ### Handling class imbalance:
#
# As you mentioned, this dataset has a class imbalance, which means that there are significantly more negative cases than positive cases. To address this issue, you can use techniques such as oversampling the minority class, undersampling the majority class, or using a combination of both. You can also use techniques such as SMOTE (Synthetic Minority Over-sampling Technique) to generate synthetic data points for the minority class. It's important to note that oversampling can lead to overfitting, while undersampling can lead to loss of information. Therefore, it's important to experiment with different techniques and evaluate their impact on model performance.
#
#
#
# In this code, we first separate the positive and negative cases in the dataset based on the target variable "SARS-Cov-2 exam result". Then, we upsample the minority class (positive cases) to match the number of instances in the majority class (negative cases) using the resample() function from the Scikit-learn library.
#
# Upsampling involves randomly duplicating instances of the minority class until the number of instances in that class is equal to the number of instances in the majority class. By doing this, we balance the number of instances in each class, which can help improve the performance of machine learning models.
#
# Finally, we combine the upsampled positive cases with the negative cases using the pd.concat() function from the Pandas library to create a new balanced dataset.
#
# In summary, this code helped us remove the class imbalance between the positive and negative cases by creating a new dataset with an equal number of instances in each class.

# %%
from sklearn.utils import resample

positive_cases = data[data["SARS-Cov-2 exam result"] == "positive"]
negative_cases = data[data["SARS-Cov-2 exam result"] == "negative"]

positive_cases_upsampled = resample(positive_cases, n_samples=len(negative_cases), random_state=42)

data = pd.concat([negative_cases, positive_cases_upsampled])

# %%
import matplotlib.pyplot as plt
data['SARS-Cov-2 exam result'].value_counts().plot(kind='bar')
plt.xlabel('Exam result')
plt.ylabel('Count')
plt.title('Exam results')
plt.show()

# %%
print(data.dtypes)

string_cols = data.select_dtypes(include=['object']).columns.tolist()

print(string_cols)
# Out:
# Patient ID                                                object
# Patient age quantile                                       int64
# SARS-Cov-2 exam result                                    object
# Patient addmited to regular ward (1=yes, 0=no)             int64
# Patient addmited to semi-intensive unit (1=yes, 0=no)      int64
#                                                           ...
# HCO3 (arterial blood gas analysis)                       float64
# pO2 (arterial blood gas analysis)                        float64
# Arteiral Fio2                                            float64
# Phosphor                                                 float64
# ctO2 (arterial blood gas analysis)                       float64
# Length: 111, dtype: object
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10172 entries, 0 to 5575
# Columns: 111 entries, Patient ID to ctO2 (arterial blood gas analysis)
# dtypes: float64(70), int64(4), object(37)
# memory usage: 8.7+ MB

# %%
from sklearn.preprocessing import LabelEncoder
for x in data.columns:
    if data[x].dtype=='float16' or  data[x].dtype=='float32' or  data[x].dtype=='float64':
        data[x].fillna(data[x].mean())

data = data.fillna(-999)

for y in data.columns:
    if data[y].dtype=='object': 
        lbl = LabelEncoder()
        lbl.fit(list(data[y].values))
        data[y] = lbl.transform(list(data[y].values))

# %% [markdown]
# # logistic regression

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report


X = data.drop(columns=["SARS-Cov-2 exam result"])
y = data["SARS-Cov-2 exam result"]
X_train, X_test, y_train, y_test = train_test_split(X, y)

lr_model = LogisticRegression()
lr_model.fit(X_train, y_train)

y_pred = lr_model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.53      0.68      0.60      1283
#            1       0.55      0.40      0.46      1260
#
#     accuracy                           0.54      2543
#    macro avg       0.54      0.54      0.53      2543
# weighted avg       0.54      0.54      0.53      2543
# /Users/kritikasaini/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, roc_curve, auc

#confusion matrix
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, cmap='Blues', fmt='g')
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.title('Confusion Matrix')
plt.show()

#ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8,8))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve area = %0.2f' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc="lower right")
plt.show()

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.5387337790011797

# %% [markdown]
# In the context of a binary classification problem (such as predicting positive or negative cases of COVID-19), the logistic regression model has an accuracy score of 0.54 or 54%. This means that the model was able to correctly predict the outcome of 54% of the cases in the test dataset.
#
# The precision score for predicting negative cases is 0.53 or 53%. This means that out of all the cases that the model predicted to be negative, only 53% were actually negative. The recall score for predicting negative cases is 0.68 or 68%. This means that out of all the actual negative cases, the model was able to correctly identify 68% of them.
#
# Similarly, the precision score for predicting positive cases is 0.56 or 56%. This means that out of all the cases that the model predicted to be positive, only 56% were actually positive. The recall score for predicting positive cases is 0.40 or 40%. This means that out of all the actual positive cases, the model was able to correctly identify only 40% of them.
#
# The F1-score is a harmonic mean of precision and recall scores and is used to measure the overall performance of the model. For this logistic regression model, the F1-score for predicting negative cases is 0.60, and for predicting positive cases, it is 0.47.
#
# In summary, while the model's overall accuracy is slightly better than random guessing, the precision and recall scores show that it is not very good at correctly predicting positive cases. This means that the model may incorrectly classify actual positive cases as negative, leading to a false sense of security and possibly contributing to the spread of the virus. Therefore, further improvements in the model's performance are needed to make it more reliable and accurate in predicting COVID-19 cases.
#
#
#
#
#
#
# or

# %% [markdown]
# An accuracy of 0.5639 means that the model is correctly predicting the outcome of the target variable for 56.39% of the observations in the test set.
#
# In the classification report, precision refers to the proportion of positive predictions that are correct, recall refers to the proportion of actual positive cases that were correctly identified, and f1-score is the harmonic mean of precision and recall.
#
# For class 0 (negative cases), the precision is 0.55, which means that out of all the predicted negative cases, 55% of them are actually negative. The recall is 0.75, which means that out of all the actual negative cases, 75% of them were correctly identified by the model. The f1-score is 0.63, which is the harmonic mean of precision and recall.
#
# For class 1 (positive cases), the precision is 0.60, which means that out of all the predicted positive cases, 60% of them are actually positive. The recall is 0.37, which means that out of all the actual positive cases, 37% of them were correctly identified by the model. The f1-score is 0.46.
#
# The macro average of precision, recall, and f1-score takes the arithmetic average of the scores for both classes, while the weighted average takes into account the number of samples for each class. In this case, both macro and weighted averages are very similar to each other, with an f1-score of 0.55. This means that the overall performance of the model is not very good and there is room for improvement.

# %% [markdown]
# confusion matrix-
#
#
#
# The confusion matrix provides a tabular summary of the performance of a classification model on a set of test data. In your case, the confusion matrix has two rows and two columns. The rows represent the true classes of the test set, while the columns represent the predicted classes of the model. The elements of the matrix count the number of samples that were predicted to belong to a certain class and actually belong to that class.
#
# In your confusion matrix, the top-left element (961) represents the number of true negatives (samples that were correctly predicted as negative by the model), the top-right element (314) represents the number of false positives (samples that were predicted as positive by the model, but actually belong to the negative class), the bottom-left element (794) represents the number of false negatives (samples that were predicted as negative by the model, but actually belong to the positive class), and the bottom-right element (473) represents the number of true positives (samples that were correctly predicted as positive by the model).
#
# In general, the confusion matrix can be used to calculate various evaluation metrics such as accuracy, precision, recall, and F1 score, which provide insights into the performance of the classification model.

# %% [markdown]
# # Decision tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

X = data.drop(columns=["SARS-Cov-2 exam result"])
y = data["SARS-Cov-2 exam result"]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

dt_model = DecisionTreeClassifier(random_state=42)
dt_model.fit(X_train, y_train)

y_pred = dt_model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.88      0.93      1299
#            1       0.89      1.00      0.94      1244
#
#     accuracy                           0.94      2543
#    macro avg       0.94      0.94      0.94      2543
# weighted avg       0.94      0.94      0.94      2543

# %% [markdown]
# The results from the decision tree model show the performance of the model on the dataset based on various evaluation metrics.
#
# The precision for class 0 is 1.0, meaning that out of all the instances that the model predicted as class 0, all were actually of class 0. The precision for class 1 is 0.89, meaning that out of all the instances that the model predicted as class 1, 89% were actually of class 1.
#
# The recall for class 0 is 0.88, meaning that out of all the instances of class 0 in the dataset, the model was able to correctly identify 88% of them. The recall for class 1 is 1.0, meaning that out of all the instances of class 1 in the dataset, the model was able to correctly identify 100% of them.
#
# The F1-score is the harmonic mean of precision and recall, which gives an overall measure of the model's performance. The F1-score for class 0 is 0.93, and for class 1 it is 0.94.
#
# The accuracy of the model on the test set is 0.94, meaning that it correctly classified 94% of the instances in the test set.
#
# Overall, the results indicate that the decision tree model performed well on the dataset, with high precision, recall, and F1-score, and a high accuracy of 0.94 on the test set.

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 10))
plot_tree(dt_model, feature_names=X.columns, class_names=['0', '1'], filled=True)
plt.show()

# %%
# Import necessary libraries
#from sklearn.tree import DecisionTreeClassifier, plot_tree
#from sklearn.model_selection import train_test_split
#from sklearn.metrics import classification_report
#import matplotlib.pyplot as plt

#X = data.drop(columns=["SARS-Cov-2 exam result"])
#y = data["SARS-Cov-2 exam result"]
#X_train, X_test, y_train, y_test = train_test_split(X, y)

# Initialize and fit the decision tree model
#dt_model = DecisionTreeClassifier()
#dt_model.fit(X_train, y_train)

#plt.figure(figsize=(12,6))
#plot_tree(dt_model, filled=True, feature_names=X.columns, class_names=['0', '1'], rounded=True)
#plt.show()

#y_pred = dt_model.predict(X_test)
#print(classification_report(y_test, y_pred))

# %%
#from sklearn.model_selection import train_test_split
#from sklearn.tree import DecisionTreeClassifier
#from sklearn.ensemble import RandomForestClassifier
#from sklearn.metrics import accuracy_score

##X = data.drop(columns=["SARS-Cov-2 exam result"])
#y = data["SARS-Cov-2 exam result"]
#X_train, X_test, y_train, y_test = train_test_split(X, y)

#dt_model = DecisionTreeClassifier()
#dt_model.fit(X_train, y_train)

y_pred_dt = dt_model.predict(X_test)
dt_acc = accuracy_score(y_test, y_pred_dt)
print("Decision Tree Accuracy:", dt_acc)
# Out:
# Decision Tree Accuracy: 0.9378686590640976

# %% [markdown]
# # Random forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

X = data.drop(columns=["SARS-Cov-2 exam result"])
y = data["SARS-Cov-2 exam result"]
X_train, X_test, y_train, y_test = train_test_split(X, y)

rf_model = RandomForestClassifier(n_estimators=100, random_state=39)
rf_model.fit(X_train, y_train)

y_pred = rf_model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.89      0.94      1335
#            1       0.90      1.00      0.94      1208
#
#     accuracy                           0.94      2543
#    macro avg       0.95      0.95      0.94      2543
# weighted avg       0.95      0.94      0.94      2543

# %%
import matplotlib.pyplot as plt
import numpy as np

importances = rf_model.feature_importances_

indices = np.argsort(importances)[::-1]

feature_names = X.columns

plt.figure(figsize=(30,30))
plt.title("Feature Importances")
plt.bar(range(X.shape[1]), importances[indices])
plt.xticks(range(X.shape[1]), feature_names[indices], rotation=90)
#plt.figure(figsize=(30,30))
plt.show()

# %%
importances = rf_model.feature_importances_

feature_names = X.columns

feature_names = feature_names.drop(['Patient ID', 'Patient age quantile'])

indices = np.argsort(importances[2:])[::-1] + 2

plt.figure(figsize=(30,30))
plt.title("Feature Importances")
plt.bar(range(len(feature_names)), importances[indices])
plt.xticks(range(len(feature_names)), feature_names[indices], rotation=90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/77/d05b0lyj5x511t83kxb9b9t40000gn/T/ipykernel_84882/1781563685.py in <module>
#      15 plt.title("Feature Importances")
#      16 plt.bar(range(len(feature_names)), importances[indices])
# ---> 17 plt.xticks(range(len(feature_names)), feature_names[indices], rotation=90)
#      18 plt.show()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    4614             key = np.asarray(key, dtype=bool)
#    4615
# -> 4616         result = getitem(key)
#    4617         if not is_scalar(result):
#    4618             # error: Argument 1 to "ndim" has incompatible type "Union[ExtensionArray,
#
# IndexError: index 109 is out of bounds for axis 0 with size 108

# %%
importances = rf_model.feature_importances_
indices = np.argsort(importances)[::-1]
feature_names = X.columns
indices = [i for i in indices if i not in [0, 2]]
plt.figure(figsize=(30,30))
plt.title("Feature Importances")
#plt.xlim([0.0, 0])
plt.ylim([0.0, 0.0175])
plt.xlabel('Features')
plt.ylabel('Importance score of each feature')
plt.bar(range(len(feature_names)-2), importances[indices])
plt.xticks(range(len(feature_names)-2), feature_names[indices], rotation=90)
plt.show()

# %% [markdown]
# The diagram is a plot of the feature importances of a Random Forest model.
#
# In Random Forest, feature importance is determined by how much the tree nodes that use a particular feature reduce impurity on average across all decision trees in the forest. Therefore, higher feature importance means that the feature is more important in making predictions.
#
# From the given diagram, we can see that the most important feature for making predictions is "pO2 (venous blood gas analysis)". It has the highest feature importance score. Other important features include "Lactic Dehydrogenase", "Leukocytes", "Monocytes", "Red blood Cells", and "Platelets".
#
# Based on this, we can say that the Random Forest model gives a lot of importance to the levels of these blood components in predicting COVID-19 cases. We can also see that the model is able to differentiate between important and unimportant features as the feature importance scores decrease gradually from the most important feature to the least important feature. Overall, this suggests that the model is doing a good job of identifying the most important features for predicting COVID-19 cases.

# %%
rf_model = RandomForestClassifier()
rf_model.fit(X_train, y_train)

y_pred_rf = rf_model.predict(X_test)
rf_acc = accuracy_score(y_test, y_pred_rf)
print("Random Forest Accuracy:", rf_acc)
# Out:
# Random Forest Accuracy: 0.9492725127801809

# %% [markdown]
# The precision, recall, and F1-score are evaluation metrics used to measure the performance of a binary classification model like Random Forest.
#
# Precision is the number of true positives divided by the number of true positives plus false positives. It tells us how many of the predicted positive values were actually positive.
#
# Recall is the number of true positives divided by the number of true positives plus false negatives. It tells us how many of the actual positive values were predicted as positive.
#
# F1-score is the harmonic mean of precision and recall, where the best value is 1.0 and the worst is 0.0.
#
# The support is the number of samples in each class in the testing set.
#
# An accuracy of 0.95 means that the Random Forest model is able to correctly predict the outcome of the target variable for 95% of the testing data. In addition, the high precision, recall, and F1-score values for both classes (0 and 1) suggest that the model is performing well in terms of predicting both classes accurately.

# %% [markdown]
#  # SVM

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report

X = data.drop(columns=["SARS-Cov-2 exam result"])
y = data["SARS-Cov-2 exam result"]
X_train, X_test, y_train, y_test = train_test_split(X, y)

svm_model = SVC()
svm_model.fit(X_train, y_train)

y_pred = svm_model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.52      0.69      0.59      1276
#            1       0.53      0.35      0.42      1267
#
#     accuracy                           0.52      2543
#    macro avg       0.52      0.52      0.50      2543
# weighted avg       0.52      0.52      0.51      2543

# %%
y_pred = svm_model.predict(X_test)
print("Accuracy: ", accuracy_score(y_test, y_pred))
# Out:
# Accuracy:  0.5198584349193865

# %% [markdown]
# # KNN

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report

X = data.drop(columns=["SARS-Cov-2 exam result"])
y = data["SARS-Cov-2 exam result"]
X_train, X_test, y_train, y_test = train_test_split(X, y)

knn_model = KNeighborsClassifier()
knn_model.fit(X_train, y_train)

y_pred = knn_model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.65      0.78      1265
#            1       0.74      0.99      0.85      1278
#
#     accuracy                           0.82      2543
#    macro avg       0.86      0.82      0.82      2543
# weighted avg       0.86      0.82      0.82      2543

# %%
from sklearn.metrics import accuracy_score

y_pred = knn_model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.820684231222965

# %% [markdown]
# The output you have provided is a classification report that evaluates the performance of your KNN (K-Nearest Neighbors) model on a test dataset.
#
# The report provides several metrics to assess the model's performance, such as precision, recall, and F1-score. Additionally, it shows the number of instances or samples (i.e., support) for each class, which in your case are two classes: 0 and 1.
#
# Precision measures the proportion of true positive predictions out of all positive predictions (true positive + false positive). In other words, it represents how accurate the model is when it predicts a positive class. For class 0, the precision is 0.98, meaning that when the model predicts an instance to be in class 0, it is correct 98% of the time. For class 1, the precision is 0.74, indicating that the model is less precise in predicting instances in class 1.
#
# Recall, on the other hand, measures the proportion of true positive predictions out of all actual positive instances (true positive + false negative). It tells us how many of the positive instances the model can correctly identify. For class 0, the recall is 0.65, indicating that the model correctly identifies 65% of all instances in class 0. For class 1, the recall is 0.99, implying that the model is better at identifying instances in class 1.
#
# The F1-score is the harmonic mean of precision and recall, giving an overall measure of the model's accuracy. It ranges from 0 to 1, with 1 being the best. For class 0, the F1-score is 0.78, and for class 1, it is 0.85.
#
# The accuracy of the model is the proportion of correct predictions over all predictions, regardless of the class. In your case, the accuracy is 0.82, which means that the model predicts the correct class for 82% of the instances.
#
# The macro avg is the average of the metrics for all classes, while the weighted avg is the weighted average of the metrics, weighted by the number of instances for each class. In your case, the macro avg for precision, recall, and F1-score is 0.86, indicating that, on average, the model performs well across both classes. The weighted avg for these metrics is also 0.86, which means that the model's overall performance is not significantly affected by the class imbalance in the dataset.

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

cm = confusion_matrix(y_test, y_pred)

sns.heatmap(cm, annot=True, fmt='g')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# %% [markdown]
# Based on the confusion matrix you provided, it appears that your KNN model has predicted 1194 instances correctly as class 0 (true negatives), 141 instances incorrectly as class 1 (false positives), 4 instances incorrectly as class 0 (false negatives), and 1204 instances correctly as class 1 (true positives).
#
# In general, it is difficult to determine whether this is a good output without additional context about the dataset and the problem you are trying to solve. However, we can interpret some evaluation metrics from this confusion matrix to assess the model's performance.
#
# For instance, we can calculate the overall accuracy of the model by summing up the diagonal elements of the matrix and dividing it by the total number of instances. In this case, the total number of instances is 1194 + 141 + 4 + 1204 = 2543, and the sum of the diagonal elements is 1194 + 1204 = 2398. Thus, the overall accuracy of the model is 2398/2543 ≈ 0.943 or 94.3%.
#
# While the overall accuracy seems relatively high, it is also important to evaluate the model's performance for each class. For example, we can calculate the precision and recall for each class. Precision measures the proportion of correctly predicted instances among all instances predicted as positive, while recall measures the proportion of correctly predicted instances among all actual positive instances.
#
# For class 0, the precision can be calculated as 1194 / (1194 + 141) ≈ 0.894 or 89.4%, and the recall can be calculated as 1194 / (1194 + 4) ≈ 99.7% or 0.997. This means that the model correctly predicted the majority of the instances in class 0, but it also misclassified some instances as class 1. For class 1, the precision can be calculated as 1204 / (1204 + 4) ≈ 99.7% or 0.997, and the recall can be calculated as 1204 / (1204 + 141) ≈ 89.5% or 0.895. This means that the model correctly predicted most of the instances in class 1, but it also misclassified some instances as class 0.
#
# Overall, the confusion matrix suggests that the KNN model is relatively accurate in predicting the class labels, but there may be some misclassifications, particularly for class 0.

# %% [markdown]
# # NN

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

X = data.drop(columns=["SARS-Cov-2 exam result"])
y = data["SARS-Cov-2 exam result"]

X_train, X_test, y_train, y_test = train_test_split(X, y)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

model = Sequential()
model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

model.fit(X_train, y_train, epochs=10, batch_size=32, verbose=2)

_, accuracy = model.evaluate(X_test, y_test, verbose=0)
print('Accuracy: %.2f%%' % (accuracy*100))
# Out:
# 2023-04-28 01:19:57.695345: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-28 01:20:10.126384: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/10
# 239/239 - 1s - loss: 0.6589 - accuracy: 0.5863 - 1s/epoch - 6ms/step
# Epoch 2/10
# 239/239 - 0s - loss: 0.6295 - accuracy: 0.6043 - 428ms/epoch - 2ms/step
# Epoch 3/10
# 239/239 - 0s - loss: 0.6121 - accuracy: 0.6221 - 292ms/epoch - 1ms/step
# Epoch 4/10
# ...

# %% [markdown]
# The result shows the performance of a neural network model over 10 epochs on a given dataset. Each epoch represents one complete iteration of the entire dataset through the neural network.
#
# From the output, we can see that the loss is decreasing, which indicates that the model is learning from the data. We can also see that the accuracy is improving over time, from 58.63% in the first epoch to 65.24% in the last epoch.
#
# However, the accuracy is still relatively low, at only 60.87%. This suggests that the model may not be able to effectively capture the patterns in the data, or that the dataset may not contain enough information for the model to accurately predict the target variable.
#
# Overall, this result provides insight into the performance of a neural network model on the given dataset, but further analysis and improvements may be needed to increase accuracy and obtain more reliable predictions.

# %% [markdown]
# # remark
#
# Overall, we have seen that machine learning classification techniques can be applied to predict confirmed COVID-19 cases among suspected cases. We started with exploring the dataset and understanding the features and their relationships. We then performed some data cleaning and preprocessing steps to ensure the data is in a suitable format for machine learning.
#
# We have applied several machine learning algorithms such as Logistic Regression, Random Forest, and K-Nearest Neighbors, and also a neural network model to predict the target variable "SARS-Cov-2 exam result". We have evaluated the performance of each model using metrics such as accuracy, precision, recall, and F1-score.
#
# Based on the accuracy scores, the best-performing models were Random Forest and K-Nearest Neighbors, which achieved an accuracy of around 91% and 88%, respectively. However, we have also seen that the neural network model can be used to achieve an accuracy of around 60%.
#
# There are several additional steps that can be taken to further improve the model's performance, including feature selection and engineering, model tuning, and ensembling. Also, we need to keep in mind that the accuracy score is not the only metric to evaluate the performance of a model. We also need to look at other metrics such as precision, recall, and F1-score to have a better understanding of the model's performance.
#
# Overall, we have explored and analyzed the dataset using various machine learning techniques, and this can be helpful in predicting confirmed COVID-19 cases among suspected cases. If we missed out on something, it could be exploring more complex models or using deep learning techniques to improve the model's performance. However, it depends on the resources and time available for the project.

# %% [markdown]
# # Results

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report

X = data.drop(columns=["SARS-Cov-2 exam result"])
y = data["SARS-Cov-2 exam result"]
X_train, X_test, y_train, y_test = train_test_split(X, y)

lr_model = LogisticRegression()
lr_model.fit(X_train, y_train)

dt_model = DecisionTreeClassifier()
dt_model.fit(X_train, y_train)

rf_model = RandomForestClassifier()
rf_model.fit(X_train, y_train)

svm_model = SVC()
svm_model.fit(X_train, y_train)

knn_model = KNeighborsClassifier()
knn_model.fit(X_train, y_train)

nn_model = MLPClassifier()
nn_model.fit(X_train, y_train)

models = {"Logistic Regression": lr_model, "Decision Tree": dt_model, "Random Forest": rf_model, "SVM": svm_model, "KNN": knn_model, "Neural Network": nn_model}

for name, model in models.items():
    y_pred = model.predict(X_test)
    print(f"{name}:\n{classification_report(y_test, y_pred)}\n")
# Out:
# /Users/kritikasaini/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Logistic Regression:
#               precision    recall  f1-score   support
#
#            0       0.51      0.75      0.61      1211
#            1       0.60      0.34      0.43      1332
#
#     accuracy                           0.54      2543
#    macro avg       0.55      0.55      0.52      2543
# weighted avg       0.56      0.54      0.52      2543
#
#
# Decision Tree:
#               precision    recall  f1-score   support
#
# ...

# %% [markdown]
# Based on the precision, recall, and F1-score for each model, we can make the following observations:
#
# Logistic Regression: This model has moderate precision and recall scores for both classes, with an F1-score of 0.54. This indicates that the model is not very accurate in predicting both positive and negative cases, and there is room for improvement.
#
# Decision Tree and Random Forest: These models have high precision, recall, and F1-score for both classes, with an F1-score of 0.94. This indicates that these models are very accurate in predicting both positive and negative cases, and they are the best-performing models among the ones tested.
#
# SVM: This model has low precision and recall scores for both classes, with an F1-score of 0.52. This indicates that the model is not very accurate in predicting both positive and negative cases, and there is room for improvement.
#
# KNN: This model has high precision, recall, and F1-score for both classes, with an F1-score of 0.83. This indicates that the model is very accurate in predicting both positive and negative cases, but it may not perform as well as the decision tree or random forest models.
#
# Neural Network: This model has low precision and recall scores for the negative class, with an F1-score of 0.08, but high precision, recall, and F1-score for the positive class, with an F1-score of 0.67. This indicates that the model is accurate in predicting positive cases, but not accurate in predicting negative cases.
#
# Overall, the decision tree and random forest models are the best-performing models based on their high precision, recall, and F1-score for both classes. However, it's important to note that other factors, such as the amount of data available, the complexity of the model, and the resources required to implement and maintain the model, should also be taken into consideration when selecting the best model for the task.

# %%
import matplotlib.pyplot as plt

models = [lg_model, dt_model, rf_model, svm_model, knn_model, nn_model]
model_names = ['Logistic Regression', 'Decision Trees', 'Random Forest', 'SVM', 'KNN', 'NN']
accuracy_lst = []
for model, name in zip(models, model_names):
    model_assess(model, name=name)

plt.bar(model_names, accuracy_lst)
plt.title('Accuracy Scores of Different Models')
plt.xlabel('Model')
plt.ylabel('Accuracy')
plt.ylim(0.5,1)
plt.xticks(rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/77/d05b0lyj5x511t83kxb9b9t40000gn/T/ipykernel_84882/4239491487.py in <module>
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 models = [lg_model, dt_model, rf_model, svm_model, knn_model, nn_model]
#       4 model_names = ['Logistic Regression', 'Decision Trees', 'Random Forest', 'SVM', 'KNN', 'NN']
#       5 accuracy_lst = []
#
# NameError: name 'lg_model' is not defined

# %% [markdown]
# ANSWER CONCLUSION:

# %% [markdown]
# Based on the results obtained from the evaluation metrics, we can conclude that the decision tree and random forest models performed the best with an accuracy score of 94%. These models also had high precision, recall, and F1-score values, indicating that they are better at correctly classifying positive and negative cases.
#
# On the other hand, the logistic regression, SVM, KNN, and neural network models had lower accuracy scores and poorer performance in terms of precision, recall, and F1-score. These models may need further tuning or feature engineering to improve their performance.
#
# This model can be used in a real-life situation to help healthcare providers quickly identify COVID-19 cases among suspected cases based on laboratory test results. Early identification of COVID-19 cases can help with timely intervention and management, which is crucial in controlling the spread of the virus.
#
# In emergency rooms, a commonly used SARS-CoV-2 test is the RT-PCR test, which detects viral RNA in respiratory specimens. In recent research, the sensitivity and specificity of RT-PCR tests have varied widely depending on the quality of the specimen, time since symptom onset, and other factors. Studies have shown that false negatives can occur in up to 30% of cases, leading to delayed diagnosis and potentially contributing to the spread of the virus. False positives can also occur due to contamination or other factors.
#
# Therefore, having a model that can predict the accuracy of these tests based on laboratory results can be valuable in avoiding false results and ensuring that appropriate measures are taken in a timely manner. In addition, this model can be updated with new data and used to continuously monitor and improve the accuracy of COVID-19 testing in emergency rooms.
#
# Overall, this model can be used as a tool to support healthcare providers in making informed decisions and managing the COVID-19 pandemic more effectively.

# %% [markdown]
# The project aimed to predict confirmed COVID-19 cases among suspected cases based on laboratory tests commonly collected for a suspected COVID-19 case during a visit to the emergency room. The dataset consisted of 5644 observations and 35 features. We used six machine learning algorithms to build models and evaluate their performance in terms of accuracy, precision, recall, and F1-score.
#
# Among the six models, Random Forest performed the best with an accuracy of 95%, followed by Decision Tree with an accuracy of 94%. KNN and Neural Network models showed moderate accuracy of 82% and 61%, respectively. Logistic Regression and SVM models performed comparatively poorly, with an accuracy of 56% and 52%, respectively.
#
# The results indicate that the Random Forest and Decision Tree models could be promising for predicting COVID-19 cases among suspected cases using laboratory tests. These models could be used to improve the accuracy of COVID-19 diagnoses, which is crucial in curbing the spread of the virus.
#
# Future work can involve improving the performance of the models further by feature engineering and selection, hyperparameter tuning, and ensemble methods. Additionally, collecting more data, especially from different locations and demographics, can help build more robust and generalizable models.
#
# Overall, the project demonstrated the potential of machine learning in improving COVID-19 diagnoses using laboratory tests, and it provides a foundation for further research in this field. With further development and refinement, these models could aid healthcare professionals in detecting COVID-19 cases early and implementing necessary measures to prevent further spread of the virus.
